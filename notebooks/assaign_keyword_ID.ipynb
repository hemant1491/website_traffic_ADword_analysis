# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **Importing the data set**

# %%
df = pd.read_excel(
    io="../data/raw/traffic_data_RAW.xls",
    sheet_name="Sheet 1 - traffic_data-adwords.",
    header=1,
)
df.head(10)
# Out:
#                                                Title  \
# 0  PMP® Exam & Certification | Flat 40% Off - Enr...
# 1  PMP® Exam & Certification | Confidently Ace Th...
# 2  PMP® Training & Exam | Special Offer: Get $400...
# 3  CSM Scrum Master Course Online | Today's Offer...
# 4   PMP® Certification | Ace PMP Exam in 1st Attempt
# 5  ITIL® 4 Certification Course | 100% Money Back...
# 6  PMP® Exam & Certification | Flat 40% Off - Enr...
# 7  CSM Scrum Master Course Online | Today's Offer...
# 8  Scrum Alliance CSM® Training | Flash Sale: Enr...
# 9  PMP® Certification Course | Ace PMP Exam in 1s...
#
#                                 Keyword  Position  Previous position  \
# 0                     pmp certification         1                  1
# 1                     pmp certification         1                  1
# 2                     pmp certification         1                  2
# 3            scrum master certification         1                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               199 non-null    object
#  1   Keyword             199 non-null    object
#  2   Position            199 non-null    int64
#  3   Previous position   199 non-null    int64
#  4   Search Volume       199 non-null    int64
#  5   CPC                 199 non-null    float64
#  6   Traffic             199 non-null    int64
#  7   Traffic (%)         199 non-null    float64
#  8   Traffic Cost        199 non-null    int64
#  9   Traffic Cost (%)    199 non-null    float64
#  10  Competition         199 non-null    float64
#  11  Number of Results   199 non-null    int64
#  12  Trends              199 non-null    object
#  13  Last Seen           199 non-null    object
#  14  Keyword Difficulty  198 non-null    float64
# dtypes: float64(5), int64(6), object(4)
# ...

# %%
df.describe()
# Out:
#          Position  Previous position  Search Volume         CPC      Traffic  \
# count  199.000000         199.000000     199.000000  199.000000   199.000000
# mean     2.532663           2.391960    4711.608040    3.916985    93.829146
# std      1.526761           1.559311   16003.015228    3.853916   446.718734
# min      1.000000           0.000000      30.000000    0.000000     0.000000
# 25%      1.000000           1.000000      70.000000    2.310000     0.500000
# 50%      2.000000           2.000000     170.000000    3.210000     3.000000
# 75%      4.000000           4.000000    1600.000000    4.485000    20.000000
# max      6.000000           6.000000   90500.000000   46.860000  4253.000000
#
#        Traffic (%)  Traffic Cost  Traffic Cost (%)  Competition  \
# count   199.000000    199.000000        199.000000   199.000000
# mean      0.498945    325.819095          0.499347     0.381658
# std       2.392012   1671.621365          2.578053     0.198629
# ...

# %% [markdown]
# #### **Creating a custom function to assign keyword ID to keywods**

# %%
def keyword_id(text):
    if "scrum" in text or "csm" in text or "smum" in text or "srum" in text:
        return 1
    elif "amazon" in text or "aws" in text or "devops" in text:
        return 2
    elif (
        "pmp" in text
        or "project management" in text
        or "pmi" in text
        or "proyectos" in text
        or "it project" in text
    ):
        return 3
    elif "cloud" in text:
        return 4
    elif "capm" in text:
        return 5
    elif "cspo" in text:
        return 6
    elif "itil" in text or "itl" in text:
        return 7
    elif (
        "simpl" in text
        or "simli" in text
        or "simpi" in text
        or "smpli" in text
        or "simi" in text
        or "sipli" in text
    ):
        return 8
    elif "safe" in text or "scale" in text:
        return 9
    elif "togaf" in text or "udacity" in text or "it architect" in text:
        return 10


df["Keyword ID"] = df["Keyword"].apply(keyword_id)
df.head(10)
# Out:
#                                                Title  \
# 0  PMP® Exam & Certification | Flat 40% Off - Enr...
# 1  PMP® Exam & Certification | Confidently Ace Th...
# 2  PMP® Training & Exam | Special Offer: Get $400...
# 3  CSM Scrum Master Course Online | Today's Offer...
# 4   PMP® Certification | Ace PMP Exam in 1st Attempt
# 5  ITIL® 4 Certification Course | 100% Money Back...
# 6  PMP® Exam & Certification | Flat 40% Off - Enr...
# 7  CSM Scrum Master Course Online | Today's Offer...
# 8  Scrum Alliance CSM® Training | Flash Sale: Enr...
# 9  PMP® Certification Course | Ace PMP Exam in 1s...
#
#                                 Keyword  Position  Previous position  \
# 0                     pmp certification         1                  1
# 1                     pmp certification         1                  1
# 2                     pmp certification         1                  2
# 3            scrum master certification         1                  1
# ...

# %% [markdown]
# #### **Creating data set with necessary columns**

# %%
website_traffic_data = pd.DataFrame(
    data=df,
    columns=[
        "Title",
        "Keyword ID",
        "Position",
        "Previous position",
        "Last Seen",
        "Search Volume",
        "CPC",
        "Traffic",
        "Traffic (%)",
        "Traffic Cost",
        "Traffic Cost (%)",
        "Competition",
        "Number of Results",
        "Keyword Difficulty",
    ],
)

website_traffic_data.head()
# Out:
#                                                Title  Keyword ID  Position  \
# 0  PMP® Exam & Certification | Flat 40% Off - Enr...           3         1
# 1  PMP® Exam & Certification | Confidently Ace Th...           3         1
# 2  PMP® Training & Exam | Special Offer: Get $400...           3         1
# 3  CSM Scrum Master Course Online | Today's Offer...           1         1
# 4   PMP® Certification | Ace PMP Exam in 1st Attempt           3         3
#
#    Previous position   Last Seen  Search Volume   CPC  Traffic  Traffic (%)  \
# 0                  1  2024-12-31          90500  3.76     4253        22.77
# 1                  1  2025-01-01          90500  3.76     4253        22.77
# 2                  2  2025-01-14          90500  3.82     1176         6.29
# 3                  1  2025-01-10          18100  3.21      850         4.55
# 4                  3  2025-01-07          90500  3.82      814         4.35
#
# ...

# %% [markdown]
# #### **Exporting the data set for further analysis**

# %%
website_traffic_data.to_csv("../data/final/website_traffic_data.csv", index=False)

# %% [markdown]
# #### **Creating Keywords table which holds unique keyword values**

# %%
def keyword(value):
    if 1 == value:
        return "Scrum Master"
    elif 2 == value:
        return "AWS"
    elif 3 == value:
        return "PMP"
    elif 4 == value:
        return "Cloud"
    elif 5 == value:
        return "CAPM"
    elif 6 == value:
        return "CSPO"
    elif 7 == value:
        return "ITIL"
    elif 8 == value:
        return "Simplilearn"
    elif 9 == value:
        return "SAFe"
    elif 10 == value:
        return "TOGAF"
    else:
        return "No Value"


website_traffic_data["Keyword"] = website_traffic_data["Keyword ID"].apply(keyword)
website_traffic_data.head(10)
# Out:
#                                                Title  Keyword ID  Position  \
# 0  PMP® Exam & Certification | Flat 40% Off - Enr...           3         1
# 1  PMP® Exam & Certification | Confidently Ace Th...           3         1
# 2  PMP® Training & Exam | Special Offer: Get $400...           3         1
# 3  CSM Scrum Master Course Online | Today's Offer...           1         1
# 4   PMP® Certification | Ace PMP Exam in 1st Attempt           3         3
# 5  ITIL® 4 Certification Course | 100% Money Back...           7         1
# 6  PMP® Exam & Certification | Flat 40% Off - Enr...           3         4
# 7  CSM Scrum Master Course Online | Today's Offer...           1         1
# 8  Scrum Alliance CSM® Training | Flash Sale: Enr...           1         1
# 9  PMP® Certification Course | Ace PMP Exam in 1s...           3         6
#
#    Previous position   Last Seen  Search Volume   CPC  Traffic  Traffic (%)  \
# ...

# %%
keywords = (
    pd.DataFrame(data=website_traffic_data, columns=["Keyword ID", "Keyword"])
    .drop_duplicates()
    .sort_values(by="Keyword ID")
)
keywords
# Out:
#     Keyword ID       Keyword
# 3            1  Scrum Master
# 53           2           AWS
# 0            3           PMP
# 88           4         Cloud
# 20           5          CAPM
# 30           6          CSPO
# 5            7          ITIL
# 10           8   Simplilearn
# 25           9          SAFe
# 46          10         TOGAF

# %% [markdown]
# #### **Exporting the keywords file**

# %%
keywords.to_csv("../data/final/keyword.csv", index=False)
